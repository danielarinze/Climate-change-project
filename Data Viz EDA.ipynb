# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\w9192864\Downloads\climate_change_impact_on_agriculture.csv")

# %%
df
# Out:
#       Year           Continents     Crop_Category  Average_Temperature_C  \
# 0     2001                 Asia  Grains (Cereals)                   1.55
# 1     2024                 Asia  Grains (Cereals)                   3.23
# 2     2001               Europe  Grains (Cereals)                  21.11
# 3     2001        North America  Industrial Crops                  27.85
# 4     1998                 Asia  Industrial Crops                   2.19
# ...    ...                  ...               ...                    ...
# 9995  2022               Europe       Fiber Crops                  30.48
# 9996  1999  Australia (Oceania)     Oilseed Crops                   9.53
# 9997  2000        South America  Industrial Crops                  31.92
# 9998  1996        South America     Oilseed Crops                  13.95
# 9999  2015                 Asia  Grains (Cereals)                  11.78
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                     447.06             15.22                 1.737
# 1                    2913.57             29.82                 1.737
# 2                    1301.74             25.75                 1.719
# 3                    1154.36             13.91                 3.890
# 4                    1627.48             11.81                 1.080
# ...                      ...               ...                   ...
# 9995                  685.93             17.64                 3.033
# 9996                 2560.38             10.68                 2.560
# 9997                  357.76             26.01                 1.161
# 9998                 1549.52             17.31                 3.348
# 9999                 1676.25              5.34                 3.710
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                          8                14.54                    10.08
# 1                          8                11.05                    33.06
# 2                          5                84.42                    27.41
# 3                          5                94.06                    14.38
# 4                          9                95.75                    44.35
# ...                      ...                  ...                      ...
# 9995                       9                27.56                    41.96
# 9996                       4                77.02                     5.45
# 9997                      10                78.53                    11.94
# 9998                       2                42.65                    44.71
# 9999                       5                46.41                    48.28
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                        14.78              83.25      Water Management
# 1                        23.25              54.02         Crop Rotation
# 2                        65.53              67.78      Water Management
# 3                        87.58              91.39         No Adaptation
# 4                        88.08              49.61         Crop Rotation
# ...                        ...                ...                   ...
# 9995                     10.95              43.41         No Adaptation
# 9996                     82.32              59.39         No Adaptation
# 9997                     26.00              41.46      Water Management
# 9998                     25.07              75.10         Crop Rotation
# 9999                     98.27              59.38      Water Management
#
#       Economic_Impact_Million_USD
# 0                          808.13
# 1                          616.22
# 2                          796.96
# 3                          790.32
# 4                          401.72
# ...                           ...
# 9995                      1483.06
# 9996                       829.61
# 9997                       155.99
# 9998                      1613.90
# 9999                       453.14
#
# [10000 rows x 14 columns]

# %%
df['Continents'].unique().size
# Out:
# 7

# %%
df['Year'].unique().size
# Out:
# 35

# %%
df['Crop_Category'].unique().size
# Out:
# 6

# %%
df['Average_Temperature_C'].unique().size
# Out:
# 3677

# %%
df['Total_Precipitation_mm'].unique().size
# Out:
# 9784

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Continents', 'Crop_Category', 'Adaptation_Strategies'], dtype='object')

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
numerical_columns
# Out:
# Index(['Year', 'Average_Temperature_C', 'Total_Precipitation_mm',
#        'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA', 'Extreme_Weather_Events',
#        'Irrigation_Access_%', 'Pesticide_Use_KG_per_HA',
#        'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Year                           0
# Continents                     0
# Crop_Category                  0
# Average_Temperature_C          0
# Total_Precipitation_mm         0
# CO2_Emissions_MT               0
# Crop_Yield_MT_per_HA           0
# Extreme_Weather_Events         0
# Irrigation_Access_%            0
# Pesticide_Use_KG_per_HA        0
# Fertilizer_Use_KG_per_HA       0
# Soil_Health_Index              0
# Adaptation_Strategies          0
# Economic_Impact_Million_USD    0
# dtype: int64

# %%
sample_data = df.sample(n=1000, random_state = 42)

# %%
sample_data
# Out:
#       Year     Continents     Crop_Category  Average_Temperature_C  \
# 6252  2001  South America  Grains (Cereals)                   2.64
# 4684  1995           Asia        Vegetables                  13.98
# 1731  1996  South America  Grains (Cereals)                  34.76
# 4742  1994           Asia  Grains (Cereals)                  19.10
# 4521  2018         Africa        Vegetables                  -2.34
# ...    ...            ...               ...                    ...
# 3921  1997  North America  Industrial Crops                  12.77
# 6685  2008         Europe  Grains (Cereals)                  24.86
# 3194  2014         Europe  Grains (Cereals)                  24.85
# 1941  1997  North America  Grains (Cereals)                   5.16
# 7713  2009        Eurasia  Grains (Cereals)                  14.44
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 6252                  514.15             21.96                 0.639
# 4684                 1940.83              6.11                 4.100
# 1731                  247.44              8.42                 2.520
# 4742                 2042.70              4.88                 1.520
# 4521                 2716.87             23.37                 1.593
# ...                      ...               ...                   ...
# 3921                 1914.95             11.19                 3.790
# 6685                 2011.86             13.15                 2.530
# 3194                 1759.39             17.14                 1.746
# 1941                 2325.27             21.93                 0.504
# 7713                  722.37             18.04                 2.169
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 6252                       4                15.95                    25.39
# 4684                       6                74.79                    33.24
# 1731                       2                52.69                     6.56
# 4742                       8                93.98                    42.48
# 4521                       6                22.09                    41.06
# ...                      ...                  ...                      ...
# 3921                       8                70.41                    14.02
# 6685                       7                20.15                    49.49
# 3194                       9                36.75                    12.15
# 1941                       9                89.68                    39.47
# 7713                       4                69.73                     5.03
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 6252                     42.58              85.01  Drought-resistant Crops
# 4684                     74.95              96.05  Drought-resistant Crops
# 1731                     10.86              56.99         Water Management
# 4742                     52.78              65.33            No Adaptation
# 4521                      8.44              99.04  Drought-resistant Crops
# ...                        ...                ...                      ...
# 3921                     60.13              39.12            Crop Rotation
# 6685                     48.71              44.48          Organic Farming
# 3194                     91.83              59.22         Water Management
# 1941                      6.23              81.74            No Adaptation
# 7713                     61.72              87.66          Organic Farming
#
#       Economic_Impact_Million_USD
# 6252                       116.07
# 4684                      1026.14
# 1731                       837.28
# 4742                       369.90
# 4521                       555.35
# ...                           ...
# 3921                       936.07
# 6685                       971.40
# 3194                       706.56
# 1941                       100.18
# 7713                       434.57
#
# [1000 rows x 14 columns]

# %%
sample_data.columns
# Out:
# Index(['Year', 'Continents', 'Crop_Category', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
# Assuming `Temperature`, `Crop Yield`, `Region`, and `Crop Type` columns exist in your dataset.

# Group by Region and Crop Type, then calculate the averages
df1 = (
    sample_data.groupby(['Continents', 'Crop_Category'])
    .agg(Average_Temperature=('Average_Temperature_C', 'mean'), 
         Average_Crop_Yield=('Crop_Yield_MT_per_HA', 'mean'))
    .reset_index()
)

# Display the resulting dataframe
df1
# Out:
#              Continents     Crop_Category  Average_Temperature  \
# 0                Africa       Fiber Crops            19.129286
# 1                Africa            Fruits            19.917778
# 2                Africa  Grains (Cereals)            11.794200
# 3                Africa  Industrial Crops            13.623684
# 4                Africa     Oilseed Crops            13.483333
# 5                Africa        Vegetables            18.082727
# 6                  Asia       Fiber Crops            14.033125
# 7                  Asia            Fruits            14.383000
# 8                  Asia  Grains (Cereals)            15.721154
# 9                  Asia  Industrial Crops            14.098400
# 10                 Asia     Oilseed Crops            15.003333
# 11                 Asia        Vegetables            15.219333
# 12  Australia (Oceania)       Fiber Crops            16.553333
# 13  Australia (Oceania)            Fruits            16.535556
# 14  Australia (Oceania)  Grains (Cereals)            15.763243
# 15  Australia (Oceania)  Industrial Crops            16.336538
# 16  Australia (Oceania)     Oilseed Crops            18.562000
# 17  Australia (Oceania)        Vegetables            18.964286
# 18              Eurasia       Fiber Crops            18.181667
# 19              Eurasia            Fruits            14.575000
# 20              Eurasia  Grains (Cereals)            16.573125
# 21              Eurasia  Industrial Crops            20.155333
# 22              Eurasia     Oilseed Crops            13.284545
# 23              Eurasia        Vegetables            20.281000
# 24               Europe       Fiber Crops            19.898889
# 25               Europe            Fruits            22.919167
# 26               Europe  Grains (Cereals)            15.618906
# 27               Europe  Industrial Crops            21.442308
# 28               Europe     Oilseed Crops            19.897778
# 29               Europe        Vegetables            19.066429
# 30        North America       Fiber Crops            14.566667
# 31        North America            Fruits            15.331500
# 32        North America  Grains (Cereals)            13.141045
# 33        North America  Industrial Crops            13.321053
# 34        North America     Oilseed Crops            12.332000
# 35        North America        Vegetables            12.681000
# 36        South America       Fiber Crops            15.620000
# 37        South America            Fruits            15.650000
# 38        South America  Grains (Cereals)            14.237614
# 39        South America  Industrial Crops            13.683000
# 40        South America     Oilseed Crops            18.633571
# 41        South America        Vegetables            17.945000
#
#     Average_Crop_Yield
# 0             2.503286
# 1             2.340667
# 2             2.196840
# 3             2.386000
# 4             2.288417
# 5             2.255182
# 6             2.510375
# 7             2.331800
# 8             2.343641
# 9             2.266500
# 10            2.181944
# 11            2.283033
# 12            2.045833
# 13            2.695444
# 14            2.579946
# 15            2.363308
# 16            3.312600
# 17            2.027143
# 18            1.900083
# 19            2.182625
# 20            2.489250
# 21            2.812667
# 22            1.655818
# 23            2.071200
# 24            2.350556
# 25            2.331250
# 26            2.377578
# 27            2.226385
# 28            2.747222
# 29            2.278000
# 30            2.144467
# 31            2.139200
# 32            2.319209
# 33            2.311579
# 34            1.998000
# 35            1.918500
# 36            2.320765
# 37            2.097700
# 38            2.283602
# 39            2.398400
# 40            2.073893
# 41            1.815900

# %%
df1.shape
# Out:
# (42, 4)

# %%
correlation = sample_data['Average_Temperature_C'].corr(sample_data['Crop_Yield_MT_per_HA'])
print(f"Correlation between Temperature and Crop Yield: {correlation}")
# Out:
# Correlation between Temperature and Crop Yield: 0.23835031397626302

# %%
# Group by Continents and Crop_Category, then calculate totals and averages
df2 = (
    sample_data.groupby(['Continents', 'Crop_Category'])
    .agg(Total_Precipitation_mm=('Total_Precipitation_mm', 'sum'), 
         Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'mean'))
    .reset_index()
)
# Display the dataframe
df2
# Out:
#              Continents     Crop_Category  Total_Precipitation_mm  \
# 0                Africa       Fiber Crops                23753.05
# 1                Africa            Fruits                16974.03
# 2                Africa  Grains (Cereals)                86531.53
# 3                Africa  Industrial Crops                27747.18
# 4                Africa     Oilseed Crops                19319.47
# 5                Africa        Vegetables                16514.00
# 6                  Asia       Fiber Crops                29957.48
# 7                  Asia            Fruits                41161.54
# 8                  Asia  Grains (Cereals)               124685.99
# 9                  Asia  Industrial Crops                78989.70
# 10                 Asia     Oilseed Crops                34159.16
# 11                 Asia        Vegetables                47568.90
# 12  Australia (Oceania)       Fiber Crops                15396.23
# 13  Australia (Oceania)            Fruits                13483.04
# 14  Australia (Oceania)  Grains (Cereals)                57519.55
# 15  Australia (Oceania)  Industrial Crops                47591.45
# 16  Australia (Oceania)     Oilseed Crops                10391.19
# 17  Australia (Oceania)        Vegetables                10448.66
# 18              Eurasia       Fiber Crops                16477.07
# 19              Eurasia            Fruits                13816.42
# 20              Eurasia  Grains (Cereals)                53111.94
# 21              Eurasia  Industrial Crops                28690.45
# 22              Eurasia     Oilseed Crops                13978.45
# 23              Eurasia        Vegetables                19979.97
# 24               Europe       Fiber Crops                12139.64
# 25               Europe            Fruits                22802.37
# 26               Europe  Grains (Cereals)               110133.13
# 27               Europe  Industrial Crops                25405.77
# 28               Europe     Oilseed Crops                13072.89
# 29               Europe        Vegetables                27225.65
# 30        North America       Fiber Crops                26041.82
# 31        North America            Fruits                32441.86
# 32        North America  Grains (Cereals)               104279.06
# 33        North America  Industrial Crops                65346.17
# 34        North America     Oilseed Crops                27334.76
# 35        North America        Vegetables                32925.36
# 36        South America       Fiber Crops                28599.00
# 37        South America            Fruits                24488.29
# 38        South America  Grains (Cereals)               130704.63
# 39        South America  Industrial Crops                44484.72
# 40        South America     Oilseed Crops                36502.06
# 41        South America        Vegetables                18174.94
#
#     Average_Crop_Yield_MT_per_HA
# 0                       2.503286
# 1                       2.340667
# 2                       2.196840
# 3                       2.386000
# 4                       2.288417
# 5                       2.255182
# 6                       2.510375
# 7                       2.331800
# 8                       2.343641
# 9                       2.266500
# 10                      2.181944
# 11                      2.283033
# 12                      2.045833
# 13                      2.695444
# 14                      2.579946
# 15                      2.363308
# 16                      3.312600
# 17                      2.027143
# 18                      1.900083
# 19                      2.182625
# 20                      2.489250
# 21                      2.812667
# 22                      1.655818
# 23                      2.071200
# 24                      2.350556
# 25                      2.331250
# 26                      2.377578
# 27                      2.226385
# 28                      2.747222
# 29                      2.278000
# 30                      2.144467
# 31                      2.139200
# 32                      2.319209
# 33                      2.311579
# 34                      1.998000
# 35                      1.918500
# 36                      2.320765
# 37                      2.097700
# 38                      2.283602
# 39                      2.398400
# 40                      2.073893
# 41                      1.815900

# %%
correlation_precip = sample_data['Total_Precipitation_mm'].corr(sample_data['Crop_Yield_MT_per_HA'])
print(f"Correlation between Precipitation and Crop Yield: {correlation_precip}")
# Out:
# Correlation between Precipitation and Crop Yield: 0.0237103128479647

# %%
# Group by Continents and Crop_Category to calculate aggregated values
df3 = (
    sample_data.groupby(['Continents', 'Crop_Category'])
    .agg(
        Total_CO2_Emissions_MT=('CO2_Emissions_MT', 'sum'),
        Total_Economic_Impact_Million_USD=('Economic_Impact_Million_USD', 'sum'),
        Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'mean')
    )
    .reset_index()
)



# Display the datafr
df3
# Out:
#              Continents     Crop_Category  Total_CO2_Emissions_MT  \
# 0                Africa       Fiber Crops                  201.28
# 1                Africa            Fruits                  122.39
# 2                Africa  Grains (Cereals)                  693.78
# 3                Africa  Industrial Crops                  259.43
# 4                Africa     Oilseed Crops                  203.70
# 5                Africa        Vegetables                  230.76
# 6                  Asia       Fiber Crops                  217.04
# 7                  Asia            Fruits                  305.06
# 8                  Asia  Grains (Cereals)                 1323.22
# 9                  Asia  Industrial Crops                  678.72
# 10                 Asia     Oilseed Crops                  314.77
# 11                 Asia        Vegetables                  378.29
# 12  Australia (Oceania)       Fiber Crops                  150.98
# 13  Australia (Oceania)            Fruits                  151.33
# 14  Australia (Oceania)  Grains (Cereals)                  542.49
# 15  Australia (Oceania)  Industrial Crops                  358.68
# 16  Australia (Oceania)     Oilseed Crops                   67.86
# 17  Australia (Oceania)        Vegetables                   79.27
# 18              Eurasia       Fiber Crops                  167.16
# 19              Eurasia            Fruits                   74.40
# 20              Eurasia  Grains (Cereals)                  461.29
# 21              Eurasia  Industrial Crops                  246.56
# 22              Eurasia     Oilseed Crops                  191.27
# 23              Eurasia        Vegetables                  162.86
# 24               Europe       Fiber Crops                  155.30
# 25               Europe            Fruits                  144.87
# 26               Europe  Grains (Cereals)                  938.18
# 27               Europe  Industrial Crops                  201.49
# 28               Europe     Oilseed Crops                  114.29
# 29               Europe        Vegetables                  215.83
# 30        North America       Fiber Crops                  238.04
# 31        North America            Fruits                  280.93
# 32        North America  Grains (Cereals)                 1076.54
# 33        North America  Industrial Crops                  495.43
# 34        North America     Oilseed Crops                  261.86
# 35        North America        Vegetables                  340.52
# 36        South America       Fiber Crops                  216.87
# 37        South America            Fruits                  316.16
# 38        South America  Grains (Cereals)                 1334.36
# 39        South America  Industrial Crops                  493.43
# 40        South America     Oilseed Crops                  378.20
# 41        South America        Vegetables                   92.23
#
#     Total_Economic_Impact_Million_USD  Average_Crop_Yield_MT_per_HA
# 0                            11520.41                      2.503286
# 1                             5672.05                      2.340667
# 2                            33164.01                      2.196840
# 3                            15070.13                      2.386000
# 4                            11089.82                      2.288417
# 5                             7171.98                      2.255182
# 6                            11898.56                      2.510375
# 7                            13459.61                      2.331800
# 8                            54285.40                      2.343641
# 9                            33725.14                      2.266500
# 10                           11964.82                      2.181944
# 11                           22177.38                      2.283033
# 12                            8116.43                      2.045833
# 13                            7382.36                      2.695444
# 14                           29887.52                      2.579946
# 15                           17450.60                      2.363308
# 16                            4850.51                      3.312600
# 17                            3684.90                      2.027143
# 18                            6308.00                      1.900083
# 19                            4870.47                      2.182625
# 20                           25143.28                      2.489250
# 21                           14266.29                      2.812667
# 22                            6638.24                      1.655818
# 23                            5605.70                      2.071200
# 24                            6717.77                      2.350556
# 25                            8822.51                      2.331250
# 26                           44415.60                      2.377578
# 27                            7833.91                      2.226385
# 28                            6578.09                      2.747222
# 29                            9525.16                      2.278000
# 30                           10629.86                      2.144467
# 31                           12079.73                      2.139200
# 32                           50855.99                      2.319209
# 33                           25571.72                      2.311579
# 34                            9566.56                      1.998000
# 35                           10870.88                      1.918500
# 36                           11722.67                      2.320765
# 37                           11974.82                      2.097700
# 38                           60290.23                      2.283602
# 39                           23293.47                      2.398400
# 40                           18250.72                      2.073893
# 41                            5669.58                      1.815900

# %%
import matplotlib.pyplot as plt

# Scatter plot with bubble size
plt.figure(figsize=(10, 6))
plt.scatter(
    df3['Total_CO2_Emissions_MT'], 
    df3['Total_Economic_Impact_Million_USD'], 
    s=df3['Average_Crop_Yield_MT_per_HA'] * 50,  # Scale bubble size
    alpha=0.6,
    edgecolors='w'
)

# Adding labels and title
plt.xlabel('Total CO2 Emissions (MT)')
plt.ylabel('Total Economic Impact (Million USD)')
plt.title('CO2 Emissions vs Economic Impact (Bubble Size: Crop Yield)')
plt.grid(True)
plt.show()

# %%
# Count frequency of extreme weather events and unique adaptation strategies by Continents and Crop_Category
df4 = (
    sample_data.groupby(['Continents', 'Crop_Category'])
    .agg(
        Frequency_Extreme_Weather_Events=('Extreme_Weather_Events', 'sum'),
        Unique_Adaptation_Strategies=('Adaptation_Strategies', lambda x: len(set(x)))
    )
    .reset_index()
)
# Display the dataframe
df4
# Out:
#              Continents     Crop_Category  Frequency_Extreme_Weather_Events  \
# 0                Africa       Fiber Crops                                75
# 1                Africa            Fruits                                54
# 2                Africa  Grains (Cereals)                               221
# 3                Africa  Industrial Crops                                92
# 4                Africa     Oilseed Crops                                63
# 5                Africa        Vegetables                                46
# 6                  Asia       Fiber Crops                               103
# 7                  Asia            Fruits                                60
# 8                  Asia  Grains (Cereals)                               364
# 9                  Asia  Industrial Crops                               281
# 10                 Asia     Oilseed Crops                                80
# 11                 Asia        Vegetables                               132
# 12  Australia (Oceania)       Fiber Crops                                58
# 13  Australia (Oceania)            Fruits                                35
# 14  Australia (Oceania)  Grains (Cereals)                               156
# 15  Australia (Oceania)  Industrial Crops                               139
# 16  Australia (Oceania)     Oilseed Crops                                22
# 17  Australia (Oceania)        Vegetables                                46
# 18              Eurasia       Fiber Crops                                55
# 19              Eurasia            Fruits                                48
# 20              Eurasia  Grains (Cereals)                               126
# 21              Eurasia  Industrial Crops                                71
# 22              Eurasia     Oilseed Crops                                43
# 23              Eurasia        Vegetables                                57
# 24               Europe       Fiber Crops                                40
# 25               Europe            Fruits                                68
# 26               Europe  Grains (Cereals)                               305
# 27               Europe  Industrial Crops                                47
# 28               Europe     Oilseed Crops                                41
# 29               Europe        Vegetables                                83
# 30        North America       Fiber Crops                                70
# 31        North America            Fruits                                92
# 32        North America  Grains (Cereals)                               379
# 33        North America  Industrial Crops                               221
# 34        North America     Oilseed Crops                                76
# 35        North America        Vegetables                               105
# 36        South America       Fiber Crops                                83
# 37        South America            Fruits                               134
# 38        South America  Grains (Cereals)                               424
# 39        South America  Industrial Crops                               127
# 40        South America     Oilseed Crops                               156
# 41        South America        Vegetables                                42
#
#     Unique_Adaptation_Strategies
# 0                              4
# 1                              3
# 2                              5
# 3                              5
# 4                              5
# 5                              4
# 6                              5
# 7                              5
# 8                              5
# 9                              5
# 10                             5
# 11                             5
# 12                             4
# 13                             4
# 14                             5
# 15                             5
# 16                             2
# 17                             4
# 18                             4
# 19                             5
# 20                             5
# 21                             5
# 22                             4
# 23                             5
# 24                             5
# 25                             5
# 26                             5
# 27                             5
# 28                             5
# 29                             5
# 30                             5
# 31                             5
# 32                             5
# 33                             5
# 34                             5
# 35                             5
# 36                             5
# 37                             4
# 38                             5
# 39                             5
# 40                             5
# 41                             4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pivot the data for heatmap
heatmap_data = df4.pivot('Continents', 'Crop_Category', 'Frequency_Extreme_Weather_Events')

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    heatmap_data, 
    annot=True, 
    fmt="d", 
    cmap="YlGnBu", 
    cbar_kws={'label': 'Frequency of Extreme Weather Events'}
)

# Add title and labels
plt.title('Heat Map: Extreme Weather Events vs Adaptation Strategies')
plt.xlabel('Crop Category')
plt.ylabel('Continents')
plt.show()
# Out:
# C:\Users\w9192864\AppData\Local\Temp\ipykernel_11644\2942983649.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   heatmap_data = df4.pivot('Continents', 'Crop_Category', 'Frequency_Extreme_Weather_Events')

# %%
# Group data by Year and calculate averages
df5 = (
    sample_data.groupby('Year')
    .agg(
        Average_Irrigation_Access_Percentage=('Irrigation_Access_%', 'mean'),
        Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'mean')
    )
    .reset_index()
)


# Display the dataframe
df5
# Out:
#     Year  Average_Irrigation_Access_Percentage  Average_Crop_Yield_MT_per_HA
# 0   1990                             50.264063                      2.289469
# 1   1991                             60.095714                      2.307029
# 2   1992                             55.572759                      2.083724
# 3   1993                             53.959667                      2.182867
# 4   1994                             63.294333                      1.869667
# 5   1995                             56.881304                      2.429130
# 6   1996                             56.816207                      2.231828
# 7   1997                             54.763333                      2.753042
# 8   1998                             59.374815                      2.163407
# 9   1999                             55.213784                      2.116162
# 10  2000                             53.426250                      2.333833
# 11  2001                             49.994516                      2.580839
# 12  2002                             56.877037                      2.435296
# 13  2003                             49.460000                      1.759913
# 14  2004                             55.790571                      2.291514
# 15  2005                             53.057931                      2.260379
# 16  2006                             56.248519                      2.395000
# 17  2007                             48.982857                      2.256333
# 18  2008                             57.888824                      2.490059
# 19  2009                             60.922400                      2.229200
# 20  2010                             51.580526                      2.499211
# 21  2011                             50.949032                      2.504097
# 22  2012                             54.486774                      2.235935
# 23  2013                             44.340000                      2.241174
# 24  2014                             48.352333                      2.421000
# 25  2015                             55.074828                      2.050310
# 26  2016                             58.653871                      2.529065
# 27  2017                             50.920476                      2.106143
# 28  2018                             57.788611                      2.514000
# 29  2019                             56.562000                      2.154733
# 30  2020                             58.622121                      2.489424
# 31  2021                             58.052083                      2.409833
# 32  2022                             66.328846                      2.200692
# 33  2023                             62.488000                      2.144857
# 34  2024                             59.025862                      2.335345

# %%
import matplotlib.pyplot as plt

# Plot the line graph
plt.figure(figsize=(12, 6))

# Line for Irrigation Access
plt.plot(
    df5['Year'], 
    df5['Average_Irrigation_Access_Percentage'], 
    label='Irrigation Access (%)', 
    color='blue', 
    marker='o'
)

# Line for Crop Yield
plt.plot(
    df5['Year'], 
    df5['Average_Crop_Yield_MT_per_HA'], 
    label='Crop Yield (MT/HA)', 
    color='green', 
    marker='o'
)

# Adding title and labels
plt.title('Irrigation Access vs Crop Yield Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage / Yield')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Group data by Region and Crop Type to calculate averages
df6 = (
    sample_data.groupby(['Continents', 'Crop_Category'])
    .agg(
        Average_Pesticide_Use_KG_per_HA=('Pesticide_Use_KG_per_HA', 'mean'),
        Average_Fertilizer_Use_KG_per_HA=('Fertilizer_Use_KG_per_HA', 'mean'),
        Average_Soil_Health_Index=('Soil_Health_Index', 'mean')  # Include soil health insight
    )
    .reset_index()
)

# Save the resulting dataframe
df6.to_csv("Pesticide_and_Fertilizer_Use.csv", index=False)

# Display the dataframe
print(df6)
# Out:
#              Continents     Crop_Category  Average_Pesticide_Use_KG_per_HA  \
# 0                Africa       Fiber Crops                        24.445000
# 1                Africa            Fruits                        23.095556
# 2                Africa  Grains (Cereals)                        21.696200
# 3                Africa  Industrial Crops                        26.671053
# 4                Africa     Oilseed Crops                        23.015833
# 5                Africa        Vegetables                        27.161818
# 6                  Asia       Fiber Crops                        20.187500
# 7                  Asia            Fruits                        25.676500
# 8                  Asia  Grains (Cereals)                        23.816667
# 9                  Asia  Industrial Crops                        27.853800
# 10                 Asia     Oilseed Crops                        18.968889
# 11                 Asia        Vegetables                        27.316333
# 12  Australia (Oceania)       Fiber Crops                        24.903333
# 13  Australia (Oceania)            Fruits                        22.845556
# 14  Australia (Oceania)  Grains (Cereals)                        26.446757
# 15  Australia (Oceania)  Industrial Crops                        27.444231
# 16  Australia (Oceania)     Oilseed Crops                        32.096000
# 17  Australia (Oceania)        Vegetables                        26.214286
# 18              Eurasia       Fiber Crops                        28.813333
# 19              Eurasia            Fruits                        18.263750
# 20              Eurasia  Grains (Cereals)                        23.630938
# 21              Eurasia  Industrial Crops                        16.431333
# 22              Eurasia     Oilseed Crops                        15.361818
# 23              Eurasia        Vegetables                        29.057000
# 24               Europe       Fiber Crops                        24.991111
# 25               Europe            Fruits                        27.831667
# 26               Europe  Grains (Cereals)                        24.253125
# 27               Europe  Industrial Crops                        29.018462
# 28               Europe     Oilseed Crops                        22.904444
# 29               Europe        Vegetables                        19.257857
# 30        North America       Fiber Crops                        26.956667
# 31        North America            Fruits                        26.744000
# 32        North America  Grains (Cereals)                        27.425075
# 33        North America  Industrial Crops                        23.611316
# 34        North America     Oilseed Crops                        29.836667
# 35        North America        Vegetables                        26.810000
# 36        South America       Fiber Crops                        26.899412
# 37        South America            Fruits                        25.491000
# 38        South America  Grains (Cereals)                        24.560795
# 39        South America  Industrial Crops                        21.690333
# 40        South America     Oilseed Crops                        23.452143
# 41        South America        Vegetables                        31.523000
#
#     Average_Fertilizer_Use_KG_per_HA  Average_Soil_Health_Index
# 0                          39.586429                  61.840000
# 1                          55.291111                  66.532222
# 2                          47.871000                  63.215600
# 3                          53.063158                  60.242105
# 4                          57.105000                  56.495000
# 5                          43.856364                  67.240909
# 6                          50.087500                  51.018750
# 7                          53.005500                  67.190000
# 8                          51.511410                  69.032692
# 9                          51.548400                  64.914600
# 10                         45.391111                  57.456667
# 11                         45.927333                  64.508333
# 12                         42.000833                  65.058333
# 13                         46.198889                  65.750000
# 14                         51.537027                  67.925405
# 15                         51.040385                  63.968846
# 16                         56.736000                  58.476000
# 17                         44.602857                  72.975714
# 18                         43.596667                  64.214167
# 19                         53.145000                  57.868750
# 20                         41.312812                  65.235625
# 21                         49.397333                  67.958000
# 22                         52.415455                  70.307273
# 23                         60.772000                  67.062000
# 24                         52.695556                  64.608889
# 25                         50.543333                  70.690000
# 26                         55.991563                  65.112656
# 27                         49.851538                  63.074615
# 28                         53.555556                  80.287778
# 29                         53.644286                  59.617857
# 30                         53.648667                  72.640667
# 31                         58.453000                  59.906500
# 32                         47.817015                  62.730448
# 33                         56.573947                  66.778421
# 34                         36.780667                  65.860667
# 35                         57.255500                  62.595000
# 36                         45.441176                  66.888824
# 37                         52.024000                  68.245000
# 38                         49.228523                  62.183523
# 39                         48.274667                  63.207333
# 40                         39.300714                  61.835714
# 41                         37.822000                  77.639000

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pivot data to reshape for bar chart
pesticide_data = df6.pivot(index='Continents', columns='Crop_Category', values='Average_Pesticide_Use_KG_per_HA')
fertilizer_data = df6.pivot(index='Continents', columns='Crop_Category', values='Average_Fertilizer_Use_KG_per_HA')

# Prepare x positions for bars
regions = df6['Continents'].unique()
x = np.arange(len(regions))

# Set bar width
bar_width = 0.6

# Initialize the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot stacked bars for each crop category
bottom_pesticide = np.zeros(len(x))  # Start stacking from 0
for crop in pesticide_data.columns:
    ax.bar(
        x, 
        pesticide_data[crop], 
        width=bar_width, 
        bottom=bottom_pesticide, 
        label=f'Pesticide Use - {crop}', 
        color=np.random.rand(3,)
    )
    bottom_pesticide += pesticide_data[crop]

bottom_fertilizer = np.zeros(len(x))  # Start stacking from 0
for crop in fertilizer_data.columns:
    ax.bar(
        x, 
        fertilizer_data[crop], 
        width=bar_width, 
        bottom=bottom_fertilizer, 
        label=f'Fertilizer Use - {crop}', 
        color=np.random.rand(3,)
    )
    bottom_fertilizer += fertilizer_data[crop]

# Set labels and title
ax.set_xticks(x)
ax.set_xticklabels(regions)
ax.set_xlabel('Regions')
ax.set_ylabel('Usage (KG/HA)')
ax.set_title('Pesticide and Fertilizer Use by Region and Crop Type')
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Group data by Region to calculate the average Soil Health Index
df7 = (
    sample_data.groupby('Continents')
    .agg(
        Average_Soil_Health_Index=('Soil_Health_Index', 'mean')
    )
    .reset_index()
)

# Save the resulting dataframe
df7.to_csv("Soil_Health_Index_by_Region.csv", index=False)

# Display the dataframe
print(df7)
# Out:
#             Continents  Average_Soil_Health_Index
# 0               Africa                  62.500174
# 1                 Asia                  64.904953
# 2  Australia (Oceania)                  66.167604
# 3              Eurasia                  65.732159
# 4               Europe                  65.902314
# 5        North America                  64.388971
# 6        South America                  64.135596

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of variables (regions in this case)
categories = df7['Continents'].tolist()
values = df7['Average_Soil_Health_Index'].tolist()

# Create the radar chart
num_vars = len(categories)

# Split the circle into even parts and save the angles for each category
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The radar chart needs to be closed, so we append the first value at the end
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Create the radar chart
ax.fill(angles, values, color='green', alpha=0.25)
ax.plot(angles, values, color='green', linewidth=2)  # Outline the area

# Add labels
ax.set_yticklabels([])  # Remove radial ticks for clarity
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)

# Add a title
ax.set_title('Soil Health Index Across Regions')

plt.tight_layout()
plt.show()

# %%
# Group data by Year to calculate unique adaptation strategies implemented each year
df8 = (
    sample_data.groupby('Year')
    .agg(
        Unique_Adaptation_Strategies=('Adaptation_Strategies', lambda x: len(set(x)))
    )
    .reset_index()
)

# Display the dataframe
print(df8)
# Out:
#     Year  Unique_Adaptation_Strategies
# 0   1990                             5
# 1   1991                             5
# 2   1992                             5
# 3   1993                             5
# 4   1994                             5
# 5   1995                             5
# 6   1996                             5
# 7   1997                             5
# 8   1998                             5
# 9   1999                             5
# 10  2000                             5
# 11  2001                             5
# 12  2002                             5
# 13  2003                             5
# 14  2004                             5
# 15  2005                             5
# 16  2006                             5
# 17  2007                             5
# 18  2008                             5
# 19  2009                             5
# 20  2010                             5
# 21  2011                             5
# 22  2012                             5
# 23  2013                             5
# 24  2014                             5
# 25  2015                             5
# 26  2016                             5
# 27  2017                             5
# 28  2018                             5
# 29  2019                             5
# 30  2020                             5
# 31  2021                             5
# 32  2022                             5
# 33  2023                             5
# 34  2024                             5

# %%
import matplotlib.pyplot as plt

# Plotting the timeline with Matplotlib
plt.figure(figsize=(12, 6))

# Create the line plot
plt.plot(df8['Year'], df8['Unique_Adaptation_Strategies'], marker='o', color='green')

# Adding labels and title
plt.title('Adaptation Strategies Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Unique Strategies Implemented')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Group the data by 'Continents' and calculate average metrics for each region
df9 = (
    sample_data.groupby('Continents')
    .agg(
        Average_Temperature_C=('Average_Temperature_C', 'mean'),
        Average_Precipitation_mm=('Total_Precipitation_mm', 'mean'),
        Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'mean')
    )
    .reset_index()
)

# Save the resulting dataframe
df9.to_csv("Regional_Impact_Overview.csv", index=False)

# Display the dataframe
print(df9)
# Out:
#             Continents  Average_Temperature_C  Average_Precipitation_mm  \
# 0               Africa              14.402957               1659.471826
# 1                 Asia              14.952830               1681.711179
# 2  Australia (Oceania)              16.468854               1612.813750
# 3              Eurasia              17.231705               1659.707955
# 4               Europe              18.004050               1741.978926
# 5        North America              13.430743               1647.823029
# 6        South America              15.249378               1466.081036
#
#    Average_Crop_Yield_MT_per_HA
# 0                      2.291791
# 1                      2.314608
# 2                      2.463188
# 3                      2.284477
# 4                      2.370702
# 5                      2.208674
# 6                      2.230798

# %%
# Group data by 'Crop_Category' to calculate the total economic impact by crop type
df10 = (
    sample_data.groupby('Crop_Category')
    .agg(
        Total_Economic_Impact_Million_USD=('Economic_Impact_Million_USD', 'sum')
    )
    .reset_index()
)

# Save the resulting dataframe
df10.to_csv("Economic_Impact_by_Crop_Type.csv", index=False)

# Display the dataframe
print(df10)
# Out:
#       Crop_Category  Total_Economic_Impact_Million_USD
# 0       Fiber Crops                           66913.70
# 1            Fruits                           64261.55
# 2  Grains (Cereals)                          298042.03
# 3  Industrial Crops                          137211.26
# 4     Oilseed Crops                           68938.76
# 5        Vegetables                           64705.58

# %%
import matplotlib.pyplot as plt

# Plot the pie chart
plt.figure(figsize=(8, 8))

# Create the pie chart with labels and percentages
plt.pie(df10['Total_Economic_Impact_Million_USD'], 
        labels=df10['Crop_Category'], 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=plt.cm.Paired.colors)

# Add a title
plt.title('Economic Impact by Crop Type (Million USD)')

# Show the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df2
# Out:
#              Continents     Crop_Category  Total_Precipitation_mm  \
# 0                Africa       Fiber Crops                23753.05
# 1                Africa            Fruits                16974.03
# 2                Africa  Grains (Cereals)                86531.53
# 3                Africa  Industrial Crops                27747.18
# 4                Africa     Oilseed Crops                19319.47
# 5                Africa        Vegetables                16514.00
# 6                  Asia       Fiber Crops                29957.48
# 7                  Asia            Fruits                41161.54
# 8                  Asia  Grains (Cereals)               124685.99
# 9                  Asia  Industrial Crops                78989.70
# 10                 Asia     Oilseed Crops                34159.16
# 11                 Asia        Vegetables                47568.90
# 12  Australia (Oceania)       Fiber Crops                15396.23
# 13  Australia (Oceania)            Fruits                13483.04
# 14  Australia (Oceania)  Grains (Cereals)                57519.55
# 15  Australia (Oceania)  Industrial Crops                47591.45
# 16  Australia (Oceania)     Oilseed Crops                10391.19
# 17  Australia (Oceania)        Vegetables                10448.66
# 18              Eurasia       Fiber Crops                16477.07
# 19              Eurasia            Fruits                13816.42
# 20              Eurasia  Grains (Cereals)                53111.94
# 21              Eurasia  Industrial Crops                28690.45
# 22              Eurasia     Oilseed Crops                13978.45
# 23              Eurasia        Vegetables                19979.97
# 24               Europe       Fiber Crops                12139.64
# 25               Europe            Fruits                22802.37
# 26               Europe  Grains (Cereals)               110133.13
# 27               Europe  Industrial Crops                25405.77
# 28               Europe     Oilseed Crops                13072.89
# 29               Europe        Vegetables                27225.65
# 30        North America       Fiber Crops                26041.82
# 31        North America            Fruits                32441.86
# 32        North America  Grains (Cereals)               104279.06
# 33        North America  Industrial Crops                65346.17
# 34        North America     Oilseed Crops                27334.76
# 35        North America        Vegetables                32925.36
# 36        South America       Fiber Crops                28599.00
# 37        South America            Fruits                24488.29
# 38        South America  Grains (Cereals)               130704.63
# 39        South America  Industrial Crops                44484.72
# 40        South America     Oilseed Crops                36502.06
# 41        South America        Vegetables                18174.94
#
#     Average_Crop_Yield_MT_per_HA
# 0                       2.503286
# 1                       2.340667
# 2                       2.196840
# 3                       2.386000
# 4                       2.288417
# 5                       2.255182
# 6                       2.510375
# 7                       2.331800
# 8                       2.343641
# 9                       2.266500
# 10                      2.181944
# 11                      2.283033
# 12                      2.045833
# 13                      2.695444
# 14                      2.579946
# 15                      2.363308
# 16                      3.312600
# 17                      2.027143
# 18                      1.900083
# 19                      2.182625
# 20                      2.489250
# 21                      2.812667
# 22                      1.655818
# 23                      2.071200
# 24                      2.350556
# 25                      2.331250
# 26                      2.377578
# 27                      2.226385
# 28                      2.747222
# 29                      2.278000
# 30                      2.144467
# 31                      2.139200
# 32                      2.319209
# 33                      2.311579
# 34                      1.998000
# 35                      1.918500
# 36                      2.320765
# 37                      2.097700
# 38                      2.283602
# 39                      2.398400
# 40                      2.073893
# 41                      1.815900

# %%
# Group by Continents and Crop_Category, then calculate totals and averages
df2 = (
    sample_data.groupby(['Crop_Category'])
    .agg(Total_Precipitation_mm=('Total_Precipitation_mm', 'sum'), 
         Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'sum'))
    .reset_index()
)
# Display the dataframe
df2
# Out:
#       Crop_Category  Total_Precipitation_mm  Average_Crop_Yield_MT_per_HA
# 0       Fiber Crops               152364.29                       215.338
# 1            Fruits               165167.55                       222.135
# 2  Grains (Cereals)               666965.83                       976.269
# 3  Industrial Crops               318255.44                       451.030
# 4     Oilseed Crops               154757.98                       214.277
# 5        Vegetables               172837.48                       216.621

# %%
# Save the resulting dataframe
df2.to_csv("crop_Categore_precipitation1.csv", index=False)

# %%
df3
# Out:
#              Continents     Crop_Category  Total_CO2_Emissions_MT  \
# 0                Africa       Fiber Crops                  201.28
# 1                Africa            Fruits                  122.39
# 2                Africa  Grains (Cereals)                  693.78
# 3                Africa  Industrial Crops                  259.43
# 4                Africa     Oilseed Crops                  203.70
# 5                Africa        Vegetables                  230.76
# 6                  Asia       Fiber Crops                  217.04
# 7                  Asia            Fruits                  305.06
# 8                  Asia  Grains (Cereals)                 1323.22
# 9                  Asia  Industrial Crops                  678.72
# 10                 Asia     Oilseed Crops                  314.77
# 11                 Asia        Vegetables                  378.29
# 12  Australia (Oceania)       Fiber Crops                  150.98
# 13  Australia (Oceania)            Fruits                  151.33
# 14  Australia (Oceania)  Grains (Cereals)                  542.49
# 15  Australia (Oceania)  Industrial Crops                  358.68
# 16  Australia (Oceania)     Oilseed Crops                   67.86
# 17  Australia (Oceania)        Vegetables                   79.27
# 18              Eurasia       Fiber Crops                  167.16
# 19              Eurasia            Fruits                   74.40
# 20              Eurasia  Grains (Cereals)                  461.29
# 21              Eurasia  Industrial Crops                  246.56
# 22              Eurasia     Oilseed Crops                  191.27
# 23              Eurasia        Vegetables                  162.86
# 24               Europe       Fiber Crops                  155.30
# 25               Europe            Fruits                  144.87
# 26               Europe  Grains (Cereals)                  938.18
# 27               Europe  Industrial Crops                  201.49
# 28               Europe     Oilseed Crops                  114.29
# 29               Europe        Vegetables                  215.83
# 30        North America       Fiber Crops                  238.04
# 31        North America            Fruits                  280.93
# 32        North America  Grains (Cereals)                 1076.54
# 33        North America  Industrial Crops                  495.43
# 34        North America     Oilseed Crops                  261.86
# 35        North America        Vegetables                  340.52
# 36        South America       Fiber Crops                  216.87
# 37        South America            Fruits                  316.16
# 38        South America  Grains (Cereals)                 1334.36
# 39        South America  Industrial Crops                  493.43
# 40        South America     Oilseed Crops                  378.20
# 41        South America        Vegetables                   92.23
#
#     Total_Economic_Impact_Million_USD  Average_Crop_Yield_MT_per_HA
# 0                            11520.41                      2.503286
# 1                             5672.05                      2.340667
# 2                            33164.01                      2.196840
# 3                            15070.13                      2.386000
# 4                            11089.82                      2.288417
# 5                             7171.98                      2.255182
# 6                            11898.56                      2.510375
# 7                            13459.61                      2.331800
# 8                            54285.40                      2.343641
# 9                            33725.14                      2.266500
# 10                           11964.82                      2.181944
# 11                           22177.38                      2.283033
# 12                            8116.43                      2.045833
# 13                            7382.36                      2.695444
# 14                           29887.52                      2.579946
# 15                           17450.60                      2.363308
# 16                            4850.51                      3.312600
# 17                            3684.90                      2.027143
# 18                            6308.00                      1.900083
# 19                            4870.47                      2.182625
# 20                           25143.28                      2.489250
# 21                           14266.29                      2.812667
# 22                            6638.24                      1.655818
# 23                            5605.70                      2.071200
# 24                            6717.77                      2.350556
# 25                            8822.51                      2.331250
# 26                           44415.60                      2.377578
# 27                            7833.91                      2.226385
# 28                            6578.09                      2.747222
# 29                            9525.16                      2.278000
# 30                           10629.86                      2.144467
# 31                           12079.73                      2.139200
# 32                           50855.99                      2.319209
# 33                           25571.72                      2.311579
# 34                            9566.56                      1.998000
# 35                           10870.88                      1.918500
# 36                           11722.67                      2.320765
# 37                           11974.82                      2.097700
# 38                           60290.23                      2.283602
# 39                           23293.47                      2.398400
# 40                           18250.72                      2.073893
# 41                            5669.58                      1.815900

# %%
# Group by Continents and Crop_Category to calculate aggregated values
df3 = (
    sample_data.groupby(['Continents'])
    .agg(
        Total_CO2_Emissions_MT=('CO2_Emissions_MT', 'sum'),
        Total_Economic_Impact_Million_USD=('Economic_Impact_Million_USD', 'sum'),
        Average_Crop_Yield_MT_per_HA=('Crop_Yield_MT_per_HA', 'sum'))
    .reset_index()
)

# Display the datafr
df3
# Out:
#             Continents  Total_CO2_Emissions_MT  \
# 0               Africa                 1711.34
# 1                 Asia                 3217.10
# 2  Australia (Oceania)                 1350.61
# 3              Eurasia                 1303.54
# 4               Europe                 1769.96
# 5        North America                 2693.32
# 6        South America                 2831.25
#
#    Total_Economic_Impact_Million_USD  Average_Crop_Yield_MT_per_HA
# 0                           83688.40                       263.556
# 1                          147510.91                       490.697
# 2                           71372.32                       236.466
# 3                           62831.98                       201.034
# 4                           83893.04                       286.855
# 5                          119574.74                       386.518
# 6                          131201.49                       430.544

# %%
# Save the resulting dataframe
df3.to_csv("CO2 and stuff.csv", index=False)
